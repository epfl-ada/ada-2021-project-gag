# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pandas==1.0.5
# Out:
# Collecting pandas==1.0.5
#   Downloading pandas-1.0.5-cp37-cp37m-manylinux1_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 4.5 MB/s
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas==1.0.5) (2018.9)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from pandas==1.0.5) (2.8.2)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.0.5) (1.19.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.6.1->pandas==1.0.5) (1.15.0)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.1.5
#     Uninstalling pandas-1.1.5:
#       Successfully uninstalled pandas-1.1.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas~=1.1.0; python_version >= "3.0", but you have pandas 1.0.5 which is incompatible.
# Successfully installed pandas-1.0.5

# %%
import pandas as pd
import numpy as np
import time
from os import listdir

# %%
df2 = pd.read_parquet('/content/drive/MyDrive/ADA/Project datasets/speaker_attributes.parquet')

# %%
df2.sample(2)
# Out:
#         aliases            date_of_birth nationality  ... candidacy  type religion
# 3600435    None  [+1965-01-05T00:00:00Z]      [Q408]  ...      None  item     None
# 7319793    None  [+1842-01-01T00:00:00Z]        None  ...      None  item     None
#
# [2 rows x 15 columns]

# %%
df = pd.read_csv('/content/drive/MyDrive/ADA/ada-sports-quotes/sport-quotes-2016.csv.bz2', compression='bz2')

# %%
df.sample(5)
# Out:
#          Unnamed: 0  ... phase
# 2028991    12295538  ...     E
# 16730        102256  ...     E
# 280294      1698080  ...     E
# 1488882     9025297  ...     E
# 1173795     7114659  ...     E
#
# [5 rows x 10 columns]

# %%
df.shape
# Out:
# (2286930, 10)

# %%
df['qids'] = df['qids'].str.strip('[]')

# %%
df['qids'] = df['qids'].str.strip('\'\'')

# %%
speakers=df2[df2['id'].isin(df['qids'])]
print(speakers)
# Out:
#                                                    aliases  ...                    religion
# 3        [George Walker Bush, Bush Jr., Dubya, GWB, Bus...  ...  [Q329646, Q682443, Q33203]
# 14       [Mary Louise Streep, Meryl Louise Streep, Stre...  ...                     [Q7066]
# 15                                [Donald Franciszek Tusk]  ...                     [Q9592]
# 18       [Namo, Modi, Narendra Bhai, Narendra Damodarda...  ...                     [Q9089]
# 22                               [Ban Kimoon, Ban Ki Moon]  ...               [Q9581, Q748]
# ...                                                    ...  ...                         ...
# 8514554                                               None  ...                        None
# 8514573  [Frederick P Rivara, Frederick Rivara, F P Riv...  ...                        None
# 8515071                                               None  ...                        None
# 8515238                                               None  ...                        None
# 8515453                                               None  ...                        None
#
# [65574 rows x 15 columns]

# %%
print(speakers.shape)
politicians=speakers[~(speakers['party'].isna())]
# Out:
# (65574, 15)

# %%
df3 = pd.read_csv('/content/drive/MyDrive/ADA/Project datasets/wikidata_labels_descriptions_quotebank.csv.bz2', compression='bz2', index_col='QID')

# %%
partys=df3[df3.index.isin((politicians['party'].str.get(0)))]
partys.sample(10)
# Out:
#                                               Label                                   Description
# QID
# Q15978686                 Democratic Party of Korea        liberal political party in South Korea
# Q17111428                 Working People's Alliance                     political party in Guyana
# Q47750                                    Lega Nord                       Italian political party
# Q1292617   Progressive Conservative Party of Canada               former Canadian political party
# Q1631384                    Parti libéral du Québec  provincial political party in Quebec, Canada
# Q216082                      Australian Labor Party                  political party in Australia
# Q1512994                                        Red                     Norwegian political party
# Q3366271                              Alberta Party            regional political party in Canada
# Q25785                           Red–Green Alliance                    political party in Denmark
# Q9669              Green Party of England and Wales          political party in England and Wales

# %%
partys.shape
# Out:
# (619, 2)
