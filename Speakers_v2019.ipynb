# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pandas==1.0.5
# Out:
# Collecting pandas==1.0.5
#   Downloading pandas-1.0.5-cp37-cp37m-manylinux1_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 4.5 MB/s
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas==1.0.5) (2018.9)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from pandas==1.0.5) (2.8.2)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.0.5) (1.19.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.6.1->pandas==1.0.5) (1.15.0)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.1.5
#     Uninstalling pandas-1.1.5:
#       Successfully uninstalled pandas-1.1.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas~=1.1.0; python_version >= "3.0", but you have pandas 1.0.5 which is incompatible.
# Successfully installed pandas-1.0.5

# %%
import pandas as pd
import numpy as np
import time
from os import listdir

# %%
df2 = pd.read_parquet('/content/drive/MyDrive/ADA/Project datasets/speaker_attributes.parquet')

# %%
df2.sample(15)
# Out:
#                                           aliases  ... religion
# 5159739                                      None  ...     None
# 7197183                                      None  ...     None
# 631495                                       None  ...     None
# 1944639                                      None  ...     None
# 34463                                        None  ...     None
# 4075048                                      None  ...     None
# 8381766  [Ann Marie Schult, Marie Schult-Slosser]  ...     None
# 4096855                                      None  ...     None
# 4148533                                      None  ...     None
# 4926785                                      None  ...     None
# 2057223                                      None  ...     None
# 2355421                 [Jean-Baptiste Lacipiere]  ...     None
# 6188180                                      None  ...     None
# 1158607                                      None  ...     None
# 5434824                                      None  ...     None
#
# [15 rows x 15 columns]

# %%
df = pd.read_csv('/content/drive/MyDrive/ADA/ada-sports-quotes/sport-quotes-2019.csv.bz2', compression='bz2')

# %%
df.sample(5)
# Out:
#          Unnamed: 0  ... phase
# 34325        254141  ...     E
# 1162600     8657454  ...     E
# 1054636     7853876  ...     E
# 1167700     8694680  ...     E
# 2250156    16751578  ...     E
#
# [5 rows x 10 columns]

# %%
df.shape
# Out:
# (2922983, 10)

# %%
df['qids'] = df['qids'].str.strip('[]')

# %%
df['qids'] = df['qids'].str.strip('\'\'')

# %%
speakers=df2[df2['id'].isin(df['qids'])]
print(speakers)
# Out:
#                                                    aliases  ...                    religion
# 3        [George Walker Bush, Bush Jr., Dubya, GWB, Bus...  ...  [Q329646, Q682443, Q33203]
# 15                                [Donald Franciszek Tusk]  ...                     [Q9592]
# 18       [Namo, Modi, Narendra Bhai, Narendra Damodarda...  ...                     [Q9089]
# 22                               [Ban Kimoon, Ban Ki Moon]  ...               [Q9581, Q748]
# 23                 [Kofi Atta Annan, Annan, Kofi A. Annan]  ...                    [Q23540]
# ...                                                    ...  ...                         ...
# 8515225                                               None  ...                        None
# 8515238                                               None  ...                        None
# 8515260                                               None  ...                        None
# 8515261                                               None  ...                        None
# 8515432                                               None  ...                        None
#
# [64583 rows x 15 columns]

# %%
print(speakers.shape)
politicians=speakers[~(speakers['party'].isna())]
# Out:
# (64583, 15)

# %%
df3 = pd.read_csv('/content/drive/MyDrive/ADA/Project datasets/wikidata_labels_descriptions_quotebank.csv.bz2', compression='bz2', index_col='QID')

# %%
partys=df3[df3.index.isin((politicians['party'].str.get(0)))]
partys.sample(10)
# Out:
#                                 Label                                        Description
# QID
# Q1258564                 New Slovenia                                    political party
# Q939248         Alberta Liberal Party                                    political party
# Q1321770        United National Party                       Political party in Sri Lanka
# Q7314655     Republican Party of Iowa  affiliate of the United States Republican Part...
# Q7889105      United Republican Party                                                NaN
# Q640379      Islamic Republican Party                                    political party
# Q5251223    Wiper Democratic Movement                             Kenyan political party
# Q2299546                  Our Ukraine                                                NaN
# Q916161   Danish Social Liberal Party                         political party in Denmark
# Q3366494    Nova Scotia Liberal Party             political party in Nova Scotia, Canada

# %%
partys.shape
# Out:
# (667, 2)
