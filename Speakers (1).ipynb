# %%
import pandas as pd
import numpy as np
df = pd.read_csv('/content/drive/MyDrive/Project datasets/wikidata_labels_descriptions_quotebank.csv.bz2', compression='bz2', index_col='QID')

# %%
df.sample(15)
# Out:
#                                                      Label                                        Description
# QID
# Q507170                              Danish People's Party                         political party in Denmark
# Q3454797                           Reformists of Vojvodina                                                NaN
# Q1278453                       Muslim Brotherhood of Syria  a branch of the Sunni Islamist Muslim Brotherhood
# Q2949890                                   Historical Left               historical Italian political faction
# Q61982                                              daimyo      powerful territorial lord in pre-modern Japan
# Q4197743                                            player                            person who plays a game
# Q19077                       Justice and Development Party  conservative-democratic political party in Turkey
# ...

# %%
df.shape
# Out:
# (36969, 2)

# %%
df2 = pd.read_parquet('/content/drive/MyDrive/Project datasets/speaker_attributes.parquet')

# %%
df2.sample(15)
# Out:
#                                 aliases            date_of_birth  ...  type religion
# 651896                             None  [+1960-02-09T00:00:00Z]  ...  item     None
# 3823503                            None  [+1942-00-00T00:00:00Z]  ...  item     None
# 3697601                            None                     None  ...  item     None
# 1662688                            None                     None  ...  item     None
# 2777306  [Stathis, Efstathios Gennatas]                     None  ...  item     None
# 678696                             None                     None  ...  item     None
# 1197549                            None  [+1827-10-06T00:00:00Z]  ...  item     None
# 7091240                      [Lee Jeni]  [+1972-01-01T00:00:00Z]  ...  item     None
# 6642710                            None  [+1927-01-01T00:00:00Z]  ...  item     None
# 7861265                            None                     None  ...  item     None
# ...

# %%
df2.shape
# Out:
# (9055981, 15)

# %%
speakers=df2[df2['id'].isin(df.index)]
print(speakers)
# Out:
#                                                    aliases  ... religion
# 6897     [Mishima Yukio, Kimitake Hiraoka, Hiraoka Kimi...  ...   [Q748]
# 10859                        [Kiyomori Taira no, Kiyomori]  ...   [Q748]
# 11714               [Tiberius Claudius Caesar Britannicus]  ...     None
# 17716    [Bill Talen, Église de la Très Sainte Consomma...  ...     None
# 23070                                                 None  ...     None
# ...                                                    ...  ...      ...
# 8150581                                  [qi zhan, Qizhan]  ...     None
# 8254126                         [Daniel Sanchez Fernandez]  ...     None
# 8290400          [Auron, Raúl Álvarez Genes, Raúl Álvarez]  ...     None
# 8444406                                               None  ...     None
# 8912707                                               None  ...     None
#
# [76 rows x 15 columns]

# %%
print(speakers.shape)
politicians=speakers[~(speakers['party'].isna())]
print(politicians.shape)
politicians.head()
# Out:
# (76, 15)
# (6, 15)
#                                                    aliases  ... religion
# 1215271                                               None  ...     None
# 2655275                                               None  ...     None
# 3398268  [Francisco Franco y Bahamonde, General Franco,...  ...  [Q1841]
# 4754358                                               None  ...     None
# 5160524                                               None  ...     None
#
# [5 rows x 15 columns]

# %%
partys=df[df.index.isin((politicians['party'].str.get(0)))]
partys.head(6)
# Out:
#                                           Label                                        Description
# QID
# Q1255232          Justice and Development Party                           Moroccan political party
# Q28229317                    Energies for Italy                            Italian political party
# Q885433               Galician Nationalist Bloc                                political coalition
# Q2630934   Unified Socialist Party of Catalonia                          dissolved political party
# Q207308            Falange Española de las JONS  political party and movement in Spain originat...
# Q216669                              monarchism          advocacy of a monarch or monarchical rule

# %%
#df3 = pd.read_csv('/content/drive/MyDrive/Project datasets/wikidata_labels_descriptions.csv.bz2', compression='bz2', index_col='QID')

# %%
#df3.shape
