# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pandas==1.0.5
# Out:
# Collecting pandas==1.0.5
#   Downloading pandas-1.0.5-cp37-cp37m-manylinux1_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 4.5 MB/s
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas==1.0.5) (2018.9)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from pandas==1.0.5) (2.8.2)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.0.5) (1.19.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.6.1->pandas==1.0.5) (1.15.0)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.1.5
#     Uninstalling pandas-1.1.5:
#       Successfully uninstalled pandas-1.1.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas~=1.1.0; python_version >= "3.0", but you have pandas 1.0.5 which is incompatible.
# Successfully installed pandas-1.0.5

# %%
import pandas as pd
import numpy as np
import time
from os import listdir

# %%
df2 = pd.read_parquet('/content/drive/MyDrive/ADA/Project datasets/speaker_attributes.parquet')

# %%
df2.sample(15)
# Out:
#                   aliases            date_of_birth  ...  type religion
# 5787463              None                     None  ...  item     None
# 3948528   [W.P. Wilstach]  [+1816-01-01T00:00:00Z]  ...  item     None
# 1541788              None                     None  ...  item     None
# 1301505              None  [+1902-04-06T00:00:00Z]  ...  item  [Q9592]
# 8325887              None                     None  ...  item     None
# 8455243              None                     None  ...  item     None
# 8426707  [Xinjun, Xiaoye]                     None  ...  item     None
# 6746930              None                     None  ...  item     None
# 6433044              None  [+1899-04-24T00:00:00Z]  ...  item     None
# 7276663              None                     None  ...  item     None
# 6187788              None  [+1997-01-25T00:00:00Z]  ...  item     None
# 7827707              None                     None  ...  item     None
# 893674               None                     None  ...  item     None
# 3162373              None                     None  ...  item     None
# 270526               None  [+1925-01-27T00:00:00Z]  ...  item     None
#
# [15 rows x 15 columns]

# %%
df = pd.read_csv('/content/drive/MyDrive/ADA/ada-sports-quotes/sport-quotes-2020.csv.bz2', compression='bz2')

# %%
df.sample(5)
# Out:
#         Unnamed: 0  ... phase
# 519722     4246860  ...     E
# 285068     2327119  ...     E
# 63171       516793  ...     E
# 167524     1368542  ...     E
# 415178     3390015  ...     E
#
# [5 rows x 10 columns]

# %%
df.shape
# Out:
# (641614, 10)

# %%
df['qids'] = df['qids'].str.strip('[]')

# %%
df['qids'] = df['qids'].str.strip('\'\'')

# %%
speakers=df2[df2['id'].isin(df['qids'])]
print(speakers)
# Out:
#                                                    aliases  ...                    religion
# 3        [George Walker Bush, Bush Jr., Dubya, GWB, Bus...  ...  [Q329646, Q682443, Q33203]
# 15                                [Donald Franciszek Tusk]  ...                     [Q9592]
# 18       [Namo, Modi, Narendra Bhai, Narendra Damodarda...  ...                     [Q9089]
# 22                               [Ban Kimoon, Ban Ki Moon]  ...               [Q9581, Q748]
# 39                                    [Ashton James Eaton]  ...                        None
# ...                                                    ...  ...                         ...
# 8512505                                               None  ...                        None
# 8513007                                               None  ...                        None
# 8513788                                               None  ...                        None
# 8515137                                               None  ...                        None
# 8515432                                               None  ...                        None
#
# [27828 rows x 15 columns]

# %%
print(speakers.shape)
politicians=speakers[~(speakers['party'].isna())]
# Out:
# (27828, 15)

# %%
df3 = pd.read_csv('/content/drive/MyDrive/ADA/Project datasets/wikidata_labels_descriptions_quotebank.csv.bz2', compression='bz2', index_col='QID')

# %%
partys=df3[df3.index.isin((politicians['party'].str.get(0)))]
partys.sample(10)
# Out:
#                                                        Label                                     Description
# QID
# Q13124                                 Free Democratic Party                      political party in Germany
# Q1757843                                   Brothers of Italy                         Italian political party
# Q55604511  Australian Labor Party (Northern Territory Bra...  territory branch of the Australian Labor Party
# Q500190                                        Liberal Party                       Norwegian political party
# Q953447                Cameroon People's Democratic Movement                     political party in Cameroon
# Q958419                                          Liga Veneta                                 political party
# Q750673                     Christian Democratic and Flemish             political party in Flanders/Belgium
# Q774542                     New Democratic Party of Manitoba                                 political party
# Q781486                                    Australian Greens                      Australian political party
# Q928435         National Movement for Stability and Progress                     political party in Bulgaria

# %%
partys.shape
# Out:
# (392, 2)
