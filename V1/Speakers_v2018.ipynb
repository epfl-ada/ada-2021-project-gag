# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pandas==1.0.5
# Out:
# Collecting pandas==1.0.5
#   Downloading pandas-1.0.5-cp37-cp37m-manylinux1_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 4.5 MB/s
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas==1.0.5) (2018.9)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from pandas==1.0.5) (2.8.2)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.0.5) (1.19.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.6.1->pandas==1.0.5) (1.15.0)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.1.5
#     Uninstalling pandas-1.1.5:
#       Successfully uninstalled pandas-1.1.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas~=1.1.0; python_version >= "3.0", but you have pandas 1.0.5 which is incompatible.
# Successfully installed pandas-1.0.5

# %%
import pandas as pd
import numpy as np
import time
from os import listdir

# %%
df2 = pd.read_parquet('/content/drive/MyDrive/ADA/Project datasets/speaker_attributes.parquet')

# %%
df2.sample(2)
# Out:
#         aliases            date_of_birth nationality  ... candidacy  type religion
# 4254590    None  [+1961-01-01T00:00:00Z]        None  ...      None  item     None
# 1811637    None  [+1962-01-01T00:00:00Z]        None  ...      None  item     None
#
# [2 rows x 15 columns]

# %%
df = pd.read_csv('/content/drive/MyDrive/ADA/ada-sports-quotes/sport-quotes-2018.csv.bz2', compression='bz2')

# %%
df.sample(5)
# Out:
#          Unnamed: 0  ... phase
# 2640795    16812204  ...     E
# 2904116    18491543  ...     E
# 1648591    10489660  ...     E
# 3630781    23124543  ...     E
# 3391427    21595121  ...     E
#
# [5 rows x 10 columns]

# %%
df.shape
# Out:
# (4274811, 10)

# %%
df['qids'] = df['qids'].str.strip('[]')

# %%
df['qids'] = df['qids'].str.strip('\'\'')

# %%
speakers=df2[df2['id'].isin(df['qids'])]
print(speakers)
# Out:
#                                                    aliases  ...                    religion
# 3        [George Walker Bush, Bush Jr., Dubya, GWB, Bus...  ...  [Q329646, Q682443, Q33203]
# 14       [Mary Louise Streep, Meryl Louise Streep, Stre...  ...                     [Q7066]
# 15                                [Donald Franciszek Tusk]  ...                     [Q9592]
# 18       [Namo, Modi, Narendra Bhai, Narendra Damodarda...  ...                     [Q9089]
# 22                               [Ban Kimoon, Ban Ki Moon]  ...               [Q9581, Q748]
# ...                                                    ...  ...                         ...
# 8514925                                               None  ...                        None
# 8514947                                               None  ...                        None
# 8515137                                               None  ...                        None
# 8515432                                               None  ...                        None
# 8515493                                               None  ...                        None
#
# [85615 rows x 15 columns]

# %%
print(speakers.shape)
politicians=speakers[~(speakers['party'].isna())]
# Out:
# (85615, 15)

# %%
df3 = pd.read_csv('/content/drive/MyDrive/ADA/Project datasets/wikidata_labels_descriptions_quotebank.csv.bz2', compression='bz2', index_col='QID')

# %%
partys=df3[df3.index.isin((politicians['party'].str.get(0)))]
partys.sample(10)
# Out:
#                                     Label                                        Description
# QID
# Q49623            Workers' Party of Korea               North Korea’s ruling political party
# Q6146742                              NaN                                                NaN
# Q1570973                   Pakatan Rakyat          dissolved political coalition in Malaysia
# Q7888308      United Nationalist Alliance                 Political party in the Philippines
# Q496810      Bangladesh Nationalist Party  Centre-right political party in Bangladesh fou...
# Q4854654  Bando Osmeña – Pundok Kauswagan                 Political party in the Philippines
# Q973542    Social Party of National Unity                                    political party
# Q2058159                  Patriotic Front                          Political party in Zambia
# Q47729                   Democratic Party                           political party in Italy
# Q3366821     Green Party of New Brunswick           political party in New Brunswick, Canada

# %%
partys.shape
# Out:
# (813, 2)
